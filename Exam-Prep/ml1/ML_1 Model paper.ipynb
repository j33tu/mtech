# %% [markdown]
# # ML-1 Graded Assessment

# %% [markdown]
# ### DATA_SET:

# %% [markdown]
# A Chinese automobile company Geely Auto contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know
#
# Based on various market surveys, the consulting firm has gathered a large dataset of different types of cars across the Americal market.

# %% [markdown]
# * Car_ID==			Unique id of each observation (Interger)
# * Symboling== 			Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.(Categorical)
# * carCompany==			Name of car company (Categorical)
# * fueltype==			Car fuel type i.e gas or diesel (Categorical)
# * aspiration==			Aspiration used in a car (Categorical)
# * doornumber==			Number of doors in a car (Categorical)
# * carbody==			body of car (Categorical)
# * drivewheel==			type of drive wheel (Categorical)
# * enginelocation==			Location of car engine (Categorical)
# * wheelbase==			Weelbase of car (Numeric)
# * carlength==			Length of car (Numeric)
# * carwidth==			Width of car (Numeric)
# * carheight==			height of car (Numeric)
# * curbweight==			The weight of a car without occupants or baggage. (Numeric)
# * enginetype==			Type of engine. (Categorical)
# * cylindernumber==			cylinder placed in the car (Categorical)
# * enginesize==			Size of car (Numeric)
# * fuelsystem==			Fuel system of car (Categorical)
# * boreratio==			Boreratio of car (Numeric)
# * stroke==			Stroke or volume inside the engine (Numeric)
# * compressionratio==			compression ratio of car (Numeric)
# * horsepower==			Horsepower (Numeric)
# * peakrpm==			car peak rpm (Numeric)
# * citympg==			Mileage in city (Numeric)
# * highwaympg==			Mileage on highway (Numeric)
# * price(Dependent variable)==			Price of car (Numeric)

# %%
# Kindly change the below cells from markdown to code and execute it 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

import csv

with open("Car_Data.csv","r")as file:

    reader=csv.reader(file)
    
df=pd.read_csv("Car_Data.csv")

df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df = df.drop(columns = ['car_ID'])

# %% [markdown]
# #### 1.	Data Understanding (5 marks)
#
#
# a.	Read the dataset (tab, csv, xls, txt, inbuilt dataset). What are the number of rows and no. of cols & types of variables (continuous, categorical etc.)? (1 MARK)
#
# b.	Calculate five-point summary for numerical variables (1 MARK)
#
# c.	Summarize observations for categorical variables – no. of categories, % observations in each category. (1 marks)
#
# d.	Check for defects in the data such as missing values, null, outliers, etc. (2 marks)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %% [markdown]
# #### 2.	Data Preparation (15 marks)
#
# a.	Fix the defects found above and do appropriate treatment if any. (5 marks)
#
# b.	Visualize the data using relevant plots. Find out the variables which are highly correlated with target variable? (5 marks)
#
# c.	Do you want to exclude some variables from the model based on this analysis? What other actions will you take? (2 marks)
#
# d.	Split dataset into train and test (70:30). Are both train and test representative of the overall data? How would you ascertain this statistically? (3 marks)

# %%
df.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.CarName.value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
df.carbody.value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
df.describe(include = [object])
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
dictt = {'one':1,'two':2,'three':3,'four':4,'five':5,'six':6}
df['cylindernumber'] = df['cylindernumber'].map(dictt)
df['doornumber'] = df['doornumber'].map(dictt)

# %%
x = df.select_dtypes(include = 'object')
for i in x.columns:
    print(x[i].value_counts(normalize = True))
# Out:
# toyota corona           0.029268
# toyota corolla          0.029268
# peugeot 504             0.029268
# subaru dl               0.019512
# mitsubishi mirage g4    0.014634
#                           ...
# mazda glc 4             0.004878
# mazda rx2 coupe         0.004878
# maxda glc deluxe        0.004878
# maxda rx3               0.004878
# volvo 246               0.004878
# Name: CarName, Length: 147, dtype: float64
# gas       0.902439
# diesel    0.097561
# Name: fueltype, dtype: float64
# std      0.819512
# turbo    0.180488
# Name: aspiration, dtype: float64
# sedan          0.468293
# hatchback      0.341463
# wagon          0.121951
# hardtop        0.039024
# convertible    0.029268
# Name: carbody, dtype: float64
# fwd    0.585366
# rwd    0.370732
# 4wd    0.043902
# Name: drivewheel, dtype: float64
# front    0.985366
# rear     0.014634
# Name: enginelocation, dtype: float64
# ohc      0.721951
# ohcf     0.073171
# ohcv     0.063415
# dohc     0.058537
# ...

# %%
sns.boxplot(data = df ,x = 'doornumber',y= 'enginesize')
# Out:
# <Axes: xlabel='doornumber', ylabel='enginesize'>

# %%
sns.pairplot(df)

# %%
sns.histplot(data = df , x = 'price' , kde = True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# Create a figure and subplots with specific sizes
fig, axs = plt.subplots(2, 2, figsize=(8, 8))

sns.boxplot(data=df, y='enginesize', ax=axs[0,0])
axs[0,0].set_title('Engine Size')

sns.boxplot(data=df, y='curbweight', ax=axs[0,1])
axs[0,1].set_title('Curb Weight')

sns.boxplot(data=df, y='peakrpm', ax=axs[1,0])
axs[1,0].set_title('peakrpm')

sns.boxplot(data=df, y='price', ax=axs[1,1])
axs[1,1].set_title('price')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
Q1 = df['enginesize'].quantile(0.25)
Q3 = df['enginesize'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

df1 = df[(df['enginesize'] >= lower_bound) & (df['enginesize'] <= upper_bound)]

# %%
sns.boxplot(data=df1, y='enginesize')
# Out:
# <Axes: ylabel='enginesize'>

# %%
df1['car_vol'] = df1.carwidth * df1.carheight * df1.carlength
df1 = df1.drop(columns = ['carlength','carwidth','carheight'])
# Out:
# C:\Users\Abhinav Bajaj\AppData\Local\Temp\ipykernel_3444\2563603079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['car_vol'] = df1.carwidth * df1.carheight * df1.carlength

# %%
df1['avg_mpg'] = (df1.citympg + df1.highwaympg) / 2
df1 = df1.drop(columns = ['citympg','highwaympg'])

# %%
df_corr = df1.corr()

plt.plot( figsize = (20,20))
sns.heatmap(df_corr, annot=True, fmt=".2f", cmap="coolwarm", linewidths=.5)
plt.show()

# %%
df1.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'curbweight',
#        'enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio',
#        'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'price',
#        'car_vol', 'avg_mpg'],
#       dtype='object')

# %%
# storke compressionratio symboling and peak rpm have very low correlation with price. Drop all columns 
df2 = df1.drop(columns = ['peakrpm','stroke','compressionratio','symboling','doornumber'])

# %%
# Also curbweight,wheelbase and car_vol seem to be highly correlated 

df_size = df2[['wheelbase','curbweight','car_vol','price']]
sns.pairplot(df_size)

# %%
df3 = df2.drop(columns = ['wheelbase','curbweight','CarName'])
df3.corr()
# Out:
#                 cylindernumber  enginesize  boreratio  horsepower     price  \
# cylindernumber        1.000000    0.733186   0.074051    0.544874  0.543020
# enginesize            0.733186    1.000000   0.618250    0.788314  0.793592
# boreratio             0.074051    0.618250   1.000000    0.546196  0.542801
# horsepower            0.544874    0.788314   0.546196    1.000000  0.779158
# price                 0.543020    0.793592   0.542801    0.779158  1.000000
# car_vol               0.275786    0.551085   0.501497    0.346168  0.565527
# avg_mpg              -0.327747   -0.629817  -0.556544   -0.760095 -0.649904
#
#                  car_vol   avg_mpg
# cylindernumber  0.275786 -0.327747
# enginesize      0.551085 -0.629817
# boreratio       0.501497 -0.556544
# horsepower      0.346168 -0.760095
# price           0.565527 -0.649904
# car_vol         1.000000 -0.525100
# avg_mpg        -0.525100  1.000000

# %%
df_obs = df3.select_dtypes(include = ['object'])
for i in df_obs:
    print(df_obs[i].value_counts(normalize = True))
# Out:
# gas       0.897436
# diesel    0.102564
# Name: fueltype, dtype: float64
# std      0.810256
# turbo    0.189744
# Name: aspiration, dtype: float64
# sedan          0.451282
# hatchback      0.358974
# wagon          0.128205
# hardtop        0.035897
# convertible    0.025641
# Name: carbody, dtype: float64
# fwd    0.615385
# rwd    0.338462
# 4wd    0.046154
# Name: drivewheel, dtype: float64
# front    0.984615
# rear     0.015385
# Name: enginelocation, dtype: float64
# ohc      0.743590
# ohcf     0.076923
# l        0.061538
# dohc     0.051282
# ohcv     0.041026
# rotor    0.020513
# dohcv    0.005128
# Name: enginetype, dtype: float64
# mpfi    0.430769
# 2bbl    0.338462
# idi     0.102564
# 1bbl    0.056410
# spdi    0.046154
# 4bbl    0.015385
# mfi     0.005128
# spfi    0.005128
# Name: fuelsystem, dtype: float64

# %%
df_cat = pd.get_dummies(df3,columns = ['fueltype','aspiration','carbody','drivewheel','enginelocation'],drop_first = True)
df_cat
# Out:
#     enginetype  cylindernumber  enginesize fuelsystem  boreratio  horsepower  \
# 0         dohc             4.0         130       mpfi       3.47         111
# 1         dohc             4.0         130       mpfi       3.47         111
# 2         ohcv             6.0         152       mpfi       2.68         154
# 3          ohc             4.0         109       mpfi       3.19         102
# 4          ohc             5.0         136       mpfi       3.19         115
# ..         ...             ...         ...        ...        ...         ...
# 200        ohc             4.0         141       mpfi       3.78         114
# 201        ohc             4.0         141       mpfi       3.78         160
# 202       ohcv             6.0         173       mpfi       3.58         134
# 203        ohc             6.0         145        idi       3.01         106
# 204        ohc             4.0         141       mpfi       3.78         114
#
# ...

# %%
dict2 = dict(df_obs.enginetype.value_counts())
dict3 = dict(df_obs.fuelsystem.value_counts(normalize = True))

# %%
df_cat['enginetype'] = df_cat['enginetype'].map(dict2)
df_cat['fuelsystem'] = df_cat['fuelsystem'].map(dict3)

# %%
df_cat = df_cat.dropna()

# %% [markdown]
# ### 3.	Model Building (20 marks)
#
# a.	Fit a base model and observe the overall R- Squared, RMSE and MAPE values of the model. Please comment on whether it is good or not.  (5 marks)
#
# b.	Check for multi-collinearity and treat the same. (3 marks)
#
# c.	How would you improve the model? Write clearly the changes that you will make before re-fitting the model. Fit the final model.   (6 marks)
#
# d.	Write down a business interpretation/explanation of the model – which variables are affecting the target the most and explain the relationship. Feel free to use charts or graphs to explain. (4 marks)
#
# e.	What changes from the base model had the most effect on model performance? (2 marks)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_cat.drop(columns = 'price')
y = df_cat['price']

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size = 0.2 , random_state =  5)

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
X_train = pd.DataFrame(sc_x.fit_transform(X_train), columns=X.columns.values)
X_test = pd.DataFrame(sc_x.transform(X_test), columns=X.columns.values)

# %%
from sklearn.linear_model import LinearRegression

# %%
mod1 = LinearRegression()

# %%
mod1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = mod1.predict(X_test)

# %%
from sklearn import metrics
import numpy as np

# Calculate metrics
r_squared = metrics.r2_score(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("R2 =",r_squared)
print("RMSE =",rmse)
print("MAPE",mape)
# Out:
# R2 = 0.8474805614286032
# RMSE = 2318.605138917163
# MAPE 15.140368617145894

# %%
X.shape
# Out:
# (194, 18)

# %%
y.shape
# Out:
# (194,)

# %%
X = df_cat.drop(columns = 'price')
y = df_cat['price']

# %%
X = sm.add_constant(X)

x_tr, x_te, y_tr, y_te = train_test_split(X, y, test_size=0.2)


m1 = sm.OLS(y_tr,x_tr).fit()

print(m1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     55.72
# Date:                Fri, 29 Mar 2024   Prob (F-statistic):           6.96e-53
# Time:                        17:19:23   Log-Likelihood:                -1401.9
# No. Observations:                 155   AIC:                             2840.
# Df Residuals:                     137   BIC:                             2895.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -5450.7803   6950.986     -0.784      0.434   -1.92e+04    8294.317
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["Predictor"] = X.columns
vif["VIF"] = [variance_inflation_factor(sm.add_constant(X).values, i) for i in range(len(X.columns))]

# %%
# Step 4: Select predictors with high VIFs
high_vif_predictors = vif[vif['VIF'] > 10]['Predictor']

# Step 5: Remove high-VIF predictors
X_reduced = X.drop(columns=high_vif_predictors)

# Step 6: Refit reduced model
model_reduced = sm.OLS(y, sm.add_constant(X_reduced)).fit()

# Step 7: Repeat if necessary
# (You may loop through steps 2-6 until all VIFs are below the threshold)

# Step 8: Evaluate the reduced model
print(model_reduced.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     75.62
# Date:                Fri, 29 Mar 2024   Prob (F-statistic):           2.47e-67
# Time:                        17:21:06   Log-Likelihood:                -1770.4
# No. Observations:                 194   AIC:                             3571.
# Df Residuals:                     179   BIC:                             3620.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                -774.6524   5067.547     -0.153      0.879   -1.08e+04    9225.165
# ...

# %%
#Applying PCA (If Necessary)
from sklearn.decomposition import PCA
pca = PCA(n_components = 5)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)
explained_variance = pca.explained_variance_ratio_

# %%
explained_variance
# Out:
# array([0.30636366, 0.12911409, 0.10108242, 0.08768882, 0.07555308])

# %%
from sklearn.linear_model import LinearRegression
lr_regressor_pca = LinearRegression()
lr_regressor_pca.fit(X_train_pca, y_train)

# Predicting Test Set
y_pred = lr_regressor_pca.predict(X_test_pca)
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2 = metrics.r2_score(y_test, y_pred)

model_results = pd.DataFrame([['Multiple Linear Regression (PCA)', mae, mse, rmse, r2]],
               columns = ['Model', 'MAE', 'MSE', 'RMSE', 'R2 Score'])

model_results
# Out:
#                               Model          MAE           MSE       RMSE  \
# 0  Multiple Linear Regression (PCA)  1757.215379  6.063737e+06  2462.4656
#
#    R2 Score
# 0  0.827967
