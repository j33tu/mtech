# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
img  = Image.open('image.png')     
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2792x1634>

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
import numpy as np

# %%
func=tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=True)
x= np.asarray(img)

# %%
# Out:
# array([[[183,  85, 175, 255],
#         [183,  85, 175, 255],
#         [183,  85, 175, 255],
#         ...,
#         [195, 111, 175, 255],
#         [195, 110, 175, 255],
#         [195, 110, 176, 255]],
#
#        [[183,  85, 174, 255],
#         [183,  85, 174, 255],
#         [183,  85, 174, 255],
#         ...,
#         [195, 110, 173, 255],
#         [195, 110, 174, 255],
#         [195, 109, 174, 255]],
#
#        [[183,  85, 173, 255],
#         [183,  85, 173, 255],
#         [183,  85, 173, 255],
#         ...,
#         [194, 109, 171, 255],
#         [194, 109, 173, 255],
#         [195, 108, 173, 255]],
#
#        ...,
#
#        [[191, 111,  41, 255],
#         [191, 111,  41, 255],
#         [193, 112,  41, 255],
#         ...,
#         [164, 137,  77, 255],
#         [163, 136,  76, 255],
#         [163, 136,  76, 255]],
#
#        [[191, 110,  40, 255],
#         [191, 111,  41, 255],
#         [191, 111,  41, 255],
#         ...,
#         [164, 137,  77, 255],
# ...
