# %% [markdown]
# #### Load Data

# %%
#Get PASCAL VOC dataset
# !wget http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar --quiet

# %%
# !tar -xf VOCtrainval_06-Nov-2007.tar

# %%
#Change it for your own dataset
img_path = 'VOCdevkit/VOC2007/JPEGImages'
xml_path = 'VOCdevkit/VOC2007/Annotations'

# %%
#!cat /content/VOCdevkit/VOC2007/Annotations/000005.xml

# %% [markdown]
# #### Load Detection Model utility

# %%
#Mount Google drive
from google.colab import drive
drive.mount('/gdrive')

# %%
#Copy xml_to_csv.py from drive to current directory. Change gdrive folder if you have saved script in some other folder
# !cp '/gdrive/My Drive/ML Content/ACV - I/Notebooks/Detection/detection_utility.py' .

# %%
import detection_utility as utility

# %%
model_url = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz'

# %%
model = utility.DetectionModel(model_url=model_url, img_path=img_path, label_path=xml_path)

# %%
# !ls -l

# %% [markdown]
# Start training...this will take some time

# %%
# !cp '/gdrive/My Drive/ML Content/ACV - I/Notebooks/Detection/ssd_mobilenet_v2_modified.config' .

# %%
model.train('ssd_mobilenet_v2_modified.config', num_steps=500)

# %% [markdown]
# #### Model Prediction

# %% [markdown]
# Image prediction

# %%
# !cp '/gdrive/My Drive/ML Content/ACV - I/Notebooks/Detection/person_with_bike.jpg' .

# %%
model.predict('person_with_bike.jpg', confidence_threshold=0.5)

# %% [markdown]
# Image Prediction with visual

# %%
model.predict('person_with_bike.jpg', confidence_threshold=0.5, show=True)

# %% [markdown]
# Review Video

# %%
# !cp '/gdrive/My Drive/ML Content/ACV - I/Notebooks/Detection/family_crossing.mp455442.webm' .

# %%
from IPython.display import HTML
from base64 import b64encode

# %%
video_file = open('family_crossing.mp455442.webm','rb').read()
data_url = "data:video/webm;base64," + b64encode(video_file).decode()

# %%
HTML("""
<video controls>
      <source src="%s" type="video/webm">
</video>
""" % data_url)

# %% [markdown]
# Video Prediction

# %%
model.process_video(videoname='family_crossing.mp455442.webm', 
                    confidence_threshold=0.5, 
                    output_dir='family.mp4')

# %%
video_file = open('family.mp4','rb').read()
data_url = "data:video/webm;base64," + b64encode(video_file).decode()

# %%
HTML("""
<video controls>
      <source src="%s" type="video/webm">
</video>
""" % data_url)
