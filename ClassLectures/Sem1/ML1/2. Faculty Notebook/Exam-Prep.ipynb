# %%
import pandas as pd
import numpy as np
df=pd.read_csv('bigmartsales-cleaned.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy     249.8            OUT049
# 1            Soft Drinks      48.3            OUT018
# 2                   Meat     141.6            OUT049
# 3  Fruits and Vegetables     182.1            OUT010
# 4              Household      53.9            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 2
# 1                       2009      Medium               Tier 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7774 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       6473 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  Profit                     8523 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7774.000000      8523.000000  8523.000000                8523.000000
# mean     11.676740         0.066132   140.998838                1997.831867
# std       5.776851         0.051598    62.258099                   8.371760
# min       0.000000         0.000000    31.300000                1985.000000
# 25%       7.720000         0.026989    93.800000                1987.000000
# 50%      11.800000         0.053931   142.700000                1999.000000
# 75%      16.500000         0.094585   185.650000                2004.000000
# max      21.350000         0.328391   266.900000                2009.000000
#
#        Item_Outlet_Sales       Profit
# count        8523.000000  8523.000000
# mean         2181.288914    13.414514
# std          1706.499616     1.701840
# min            33.290000     0.100000
# 25%           834.247400    13.150000
# 50%          1794.331000    13.900000
# ...

# %%
df.describe(include='object')
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                2                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             5517                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 6473               8523
# unique                10           3                    8                  4
# top               OUT027      Medium               Tier 2  Supermarket Type1
# freq                 935        2793                 2793               5577

# %%
df.isnull().values.any()
# Out:
# True

# %%
missing_values=df.isnull().sum()
missing_values
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.isnull())
#df.isnull()
# Out:
# <Axes: >

# %%
total_count=df.isnull().sum().sort_values(ascending=False)

# %%
percent=((df.isnull().sum()/df.shape[0])*100)
percent=percent.sort_values(ascending=False)
percent
# Out:
# Outlet_Size                  28.276428
# Outlet_Location_Type         24.052564
# Item_Weight                   8.787985
# Item_Identifier               0.000000
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# Profit                        0.000000
# dtype: float64

# %%
missing_data=pd.concat([total_count,percent],axis=1,keys=['total_count','percent'])

# %%
missing_data['type']=df[missing_data.index].dtypes

# %%
missing_data
# Out:
#                            total_count    percent     type
# Outlet_Size                       2410  28.276428   object
# Outlet_Location_Type              2050  24.052564   object
# Item_Weight                        749   8.787985  float64
# Item_Identifier                      0   0.000000   object
# Item_Fat_Content                     0   0.000000   object
# Item_Visibility                      0   0.000000  float64
# Item_Type                            0   0.000000   object
# Item_MRP                             0   0.000000  float64
# Outlet_Identifier                    0   0.000000   object
# Outlet_Establishment_Year            0   0.000000    int64
# Outlet_Type                          0   0.000000   object
# Item_Outlet_Sales                    0   0.000000  float64
# Profit                               0   0.000000  float64

# %%
df.Outlet_Size.isnull().sum()
# Out:
# 2410

# %%
df.Outlet_Size.value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df.Outlet_Size.mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df.Outlet_Size.head(10)
# Out:
# 0    Medium
# 1    Medium
# 2    Medium
# 3       NaN
# 4      High
# 5    Medium
# 6      High
# 7    Medium
# 8       NaN
# 9       NaN
# Name: Outlet_Size, dtype: object

# %%
df.Outlet_Size.replace(np.NaN,'Medium',inplace=True)

# %%
df.Outlet_Size.isnull().sum()
# Out:
# 0

# %%
df.Outlet_Location_Type.isnull().sum()
# Out:
# 2050

# %%
df.Outlet_Location_Type.value_counts()
# Out:
# Outlet_Location_Type
# Tier 2    2793
# Tier1     2388
# Tier 3     932
# ?          120
#   --       109
#   -         67
# na          48
# NAN         16
# Name: count, dtype: int64

# %%
df.Outlet_Location_Type.replace('NAN',np.NaN,inplace=True)
df.Outlet_Location_Type.replace('  --',np.NaN,inplace=True)
df.Outlet_Location_Type.replace('  -',np.NaN,inplace=True)
df.Outlet_Location_Type.replace('na',np.NaN,inplace=True)
df.Outlet_Location_Type.replace('?',np.NaN,inplace=True)

# %%
df.Outlet_Location_Type.value_counts()
df.Outlet_Location_Type.isnull().sum()
# Out:
# 2410

# %%
df.Outlet_Location_Type.mode()
# Out:
# 0    Tier 2
# Name: Outlet_Location_Type, dtype: object

# %%
# we need to replace based on other columns 
df_impute=df[['Item_Outlet_Sales','Outlet_Location_Type']].dropna()
df_impute=df_impute.groupby(df_impute['Outlet_Location_Type']).mean()
df_impute
# Out:
#                       Item_Outlet_Sales
# Outlet_Location_Type
# Tier 2                      2681.603542
# Tier 3                      2298.995256
# Tier1                       1912.149161

# %%
index=np.where(df.Outlet_Location_Type.isnull())[0]
index
# Out:
# array([   3,    8,    9, ..., 8509, 8514, 8519], dtype=int64)

# %%
for ind in index:
    if df.loc[ind,'Item_Outlet_Sales'] <=2100:
        df.loc[ind,'Outlet_Location_Type'] ='Tier 1'
    elif df.loc[ind,'Item_Outlet_Sales'] >=2500:
        df.loc[ind,'Outlet_Location_Type'] ='Tier 2'
    else:
        df.loc[ind,'Outlet_Location_Type'] ='Tier 3'

# %%
for ind in index:                                               # for the rows containing missing data
    if df.loc[ind,"Item_Outlet_Sales"] <= 2100:           # if the sales is less than 2100 for the location
        df.loc[ind,"Outlet_Location_Type"] = "Tier1"      # impute the value "Tier1"
    elif df.loc[ind,"Item_Outlet_Sales"] >= 2500:         # if the sales is more than 2500 for the location
        df.loc[ind,"Outlet_Location_Type"] = "Tier 2"     # impute the value "Tier 2"
    else:                                                       # if both the if conditions fail
        df.loc[ind,"Outlet_Location_Type"] = "Tier 3"

# %%
df.Outlet_Location_Type.isnull().sum()
# Out:
# 0

# %%
df.Item_Weight.describe()
# Out:
# count    7774.000000
# mean       11.676740
# std         5.776851
# min         0.000000
# 25%         7.720000
# 50%        11.800000
# 75%        16.500000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df.Item_Weight.isnull().sum()
# Out:
# 749

# %%
df.Item_Weight.replace(0,np.NaN,inplace=True)

# %%
df.Item_Weight.describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df.Item_Weight.isnull().sum()
# Out:
# 1463

# %%
from matplotlib import gridspec

# %%
df_mean=df
df_mean.Item_Weight.replace(np.NaN,df_mean.Item_Weight.mean())
df_mean.Item_Weight.describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df.Item_Weight.describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_med1=df
df_med1.Item_Weight.replace(np.NaN,df_med1.Item_Weight.median())
df_med1.Item_Weight.describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df.Item_Weight.fillna(df.Item_Weight.median(),inplace=True)
df.Item_Weight.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Profit                       0
# dtype: int64

# %%
# display the summary 
df["Item_Visibility"].describe()
# Out:
# count    8523.000000
# mean        0.066132
# std         0.051598
# min         0.000000
# 25%         0.026989
# 50%         0.053931
# 75%         0.094585
# max         0.328391
# Name: Item_Visibility, dtype: float64

# %%
df.Item_Visibility.replace(0,df.Item_Visibility.mean(),inplace=True)

# %%
df["Item_Visibility"].describe()
# Out:
# count    8523.000000
# mean        0.070213
# std         0.048742
# min         0.003575
# 25%         0.033085
# 50%         0.062517
# 75%         0.094585
# max         0.328391
# Name: Item_Visibility, dtype: float64

# %%
missing_values = df.isnull().sum()
# let us plot a heatmap of the missing values

# import the required libraries
# import the library seaborn and matplotlib
import seaborn as sns

# plot a heatmap of the missing values in the data
# cbar: specify whether to display the color index or not
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
df.Item_Type.value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
#create Getdummies variablefor itemtypes


pd.get_dummies(df,columns=['Item_Type'],dtype=int).head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           FDA15         9.30          Low Fat         0.016047     249.8
# 1           DRC01         5.92          Regular         0.019278      48.3
# 2           FDN15        17.50          Low Fat         0.016760     141.6
# 3           FDX07        19.20          Regular         0.066132     182.1
# 4           NCD19         8.93          Low Fat         0.066132      53.9
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
# 2            OUT049                       1999      Medium
# 3            OUT010                       1998      Medium
# 4            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  ...  \
# 0               Tier 2  Supermarket Type1  ...
# 1               Tier 2  Supermarket Type2  ...
# ...

# %%
## sklearn also provides 1hot encoding using SKLearn
from sklearn.preprocessing import OneHotEncoder

encode=OneHotEncoder()


df_encode=pd.DataFrame(encode.fit_transform(df[['Outlet_Type']]).toarray(),columns=['Grocery Store', 'Supermarket Type1','Supermarket Type2', 'Supermarket Type3'])
df1=df
df1=pd.concat([df,df_encode],axis=1)
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
# one encoding using get dummies on Item_Type
df12=df
df12

df12=pd.get_dummies(df12,columns=['Item_Type'],dtype=int).head()

# %%
# one encoding using get dummies on Outlet_Type
dfout=df
df_out=pd.get_dummies(dfout,columns=['Outlet_Type'],dtype=int)
df_out
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
# one encoding using sklearn on Outlet_Type
dfsk1=df
from sklearn.preprocessing import OneHotEncoder
onehotencoe=OneHotEncoder()

dftemp=pd.DataFrame(onehotencoe.fit_transform(dfsk1[['Outlet_Type']]).toarray(),columns=['Grocery Store', 'Supermarket Type1','Supermarket Type2', 'Supermarket Type3'])

dfsk1=pd.concat([dfsk1,dftemp],axis=1)
dfsk1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
# lebel encoding using SKLERAN
#check catagories in Outlet_Size


df.Outlet_Size.unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

df['Labeled_Outlet_Size']=labelencoder.fit_transform(df.Outlet_Size)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinalencoder=OrdinalEncoder(categories=[['Small','Medium','High','Nan']])
dftp=df

dftp['ordinal_encoding']=ordinalencoder.fit_transform(dftp.Outlet_Size.values.reshape(-1,1))
dftp
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
## frequency encodingfor Item_type

encoding=df.groupby('Item_Type').size()
encoding


#frequency
encoding=encoding/len(df)
encoding


df['frequncy_encoding']=df.Item_Type.map(encoding)*100

df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
pd.DataFrame(df['Item_Type'].unique(),df['frequncy_encoding'].unique(),columns=['Item_Type'])
# Out:
#                        Item_Type
# 8.001877                   Dairy
# 5.221166             Soft Drinks
# 4.986507                    Meat
# 14.455004  Fruits and Vegetables
# 10.676992              Household
# 7.602957            Baking Goods
# 14.079549            Snack Foods
# 10.043412           Frozen Foods
# 1.290625               Breakfast
# 6.101138      Health and Hygiene
# 2.510853             Hard Drinks
# 7.614690                  Canned
# 2.944972                  Breads
# 1.736478           Starchy Foods
# 1.982870                  Others
# 0.750909                 Seafood

# %%
df['Item_Outlet_Sales'].min()
# Out:
# 33.29

# %%
df['Item_Outlet_Sales'].max()
# Out:
# 13086.9648

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
standard_scale=StandardScaler()
df['scaled_Item_Outlet_Sales']=standard_scale.fit_transform(df[['Item_Outlet_Sales']])

df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
sns.distplot(df.scaled_Item_Outlet_Sales)
# Out:
# C:\Users\jitendra\AppData\Local\Temp\ipykernel_11240\3888123870.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.scaled_Item_Outlet_Sales)
# <Axes: xlabel='scaled_Item_Outlet_Sales', ylabel='Density'>

# %%
sns.distplot(df.Item_Outlet_Sales)
# Out:
# C:\Users\jitendra\AppData\Local\Temp\ipykernel_11240\1660646073.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Item_Outlet_Sales)
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
from sklearn.metrics import mean_squared_error

# Actual values
actual = np.array([3, -0.5, 2, 7])

# Predicted values
predicted = np.array([2.5, 0.0, 2, 8])

RMSE=mean_squared_error(actual,predicted)

RMSE
# Out:
# 0.375
