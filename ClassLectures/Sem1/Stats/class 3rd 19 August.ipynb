# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns

# %%
n=3
p=0.5
st.binom.stats(n,p)
# Out:
# (1.5, 0.75)

# %%
lambda=3.5
p=0.5
st.binom.stats(n,p)
# Out:
#   Cell In[7], line 1
#     lambda=3.5
#           ^
# SyntaxError: invalid syntax

# %%
data=st.norm.rvs(30,10,100)
sns.distplot(data)
# Out:
# /var/folders/w4/b4glxfbd7c1522mj2spjmg4r0000gn/T/ipykernel_13396/3401453561.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data)
# <Axes: ylabel='Density'>

# %%
#high of a lernede folws normal distrbutions with a mean of 5.5 Feet and stt.deviation of 0.25 Feet
#Find the probablity of the person is having height of 
#1. Less than 5 Feet
#2. more than 5 feet
#3. nte betweeen 5 and 5.7
#4. in between  5.25 and 5.75? mu +- 1 sigma
#5 in bw 5 and 6  mu +- 2 sigma
#in between 4.75 and 6.25 (mu +- 3 Sigma)

# %%
mu=5.5 ## mean
sigma = 0.25 ## standard deviation
data=st.norm.rvs(5.5,.25,100)
sns.distplot(data)
# Out:
# /var/folders/w4/b4glxfbd7c1522mj2spjmg4r0000gn/T/ipykernel_13396/1585955282.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data)
# <Axes: ylabel='Density'>

# %%
#1. Less than 5 Feet P(x<=5)=?
st.norm.cdf(5,mu,sigma)
# Out:
# 0.022750131948179195

# %%
#2. more than 5 feet P(x>5)
st.norm.sf(5,mu,sigma) or # 1-st.norm.cdf(5,mu,sigma)
# Out:
# 0.9772498680518208

# %%
#3. nte betweeen 5 and 5.7  001 index

st.norm.cdf(5.75,mu,sigma) - st.norm.cdf(5,mu,sigma) ## cdf way
# Out:
# 0.8185946141203637

# %%
st.norm.sf(5,mu,sigma) - st.norm.sf(5.75,mu,sigma)  ## sf way
# Out:
# 0.8185946141203637

# %%
1- st.norm.cdf(5,mu,sigma) - st.norm.sf(5.75,mu,sigma)
# Out:
# 0.8185946141203637

# %%
#4. in between  5.25 and 5.75? mu +- 1 sigma
1- st.norm.cdf(5.25,mu,sigma) - st.norm.sf(5.75,mu,sigma)
# Out:
# 0.6826894921370859

# %%
# Out:
# -0.6826894921370859

# %%
#5 in bw 5 and 6  mu +- 2 sigma
1- st.norm.cdf(5,mu,sigma) - st.norm.sf(6,mu,sigma)
# Out:
# 0.9544997361036416

# %%
#in between 4.75 and 6.25 (mu +- 3 Sigma)
1- (st.norm.cdf(4.75,mu,sigma) + st.norm.sf(6.25,mu,sigma))
# Out:
# 0.9973002039367398

# %%
## what is maximum height of 2.2750131948179195 % people
st.norm.ppf(0.022750131948179195,mu,sigma)
# Out:
# 5.0

# %%
## what is Minimum height of 97.72498680518208 % people
st.norm.isf(0.9772498680518208,mu,sigma)
# Out:
# 5.0

# %%
## 
df=sns.load_dataset('tips')
xbar=df.total_bill.mean()
sd=df.total_bill.std()
z_tb=(df.total_bill-xbar)/sd
sns.distplot(z_tb)
# Out:
# /var/folders/w4/b4glxfbd7c1522mj2spjmg4r0000gn/T/ipykernel_13396/3838060770.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_tb)
# <Axes: xlabel='total_bill', ylabel='Density'>
