# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds41.csv')
df1

# %%
#x1 = [1,2,3,4,5,6]
#y1 = [10,13,14,15,16,17]
plt.xlabel('x-axis')
plt.ylabel('x-axis')
plt.title('my first plot')
plt.scatter(df1.cyl,df1.disp,color='green',marker='*') #bivariant needs two values

# %%
ps1=df1.gear.value_counts()
plt.scatter(x=df1.gear,y=df1.mpg,color='green',marker='*')
plt.xticks=(ps1.index)
plt.show()

# %%
df1.plot(kind='scatter',x='gear',y='mpg',color='green')
# Out:
# <Axes: xlabel='gear', ylabel='mpg'>
